# %% [markdown]
# # House Prices: Advanced Regression Techniques
# https://www.kaggle.com/c/house-prices-advanced-regression-techniques

# %%
import pandas as pd
import numpy as np

# %%
train=pd.read_csv("house-prices-advanced-regression-techniques/train.csv")
test=pd.read_csv("house-prices-advanced-regression-techniques/test.csv")

# %%
train.isnull().sum()[train.isnull().sum()>0]
# Out:
# LotFrontage      259
# Alley           1369
# MasVnrType         8
# MasVnrArea         8
# BsmtQual          37
# BsmtCond          37
# BsmtExposure      38
# BsmtFinType1      37
# BsmtFinType2      38
# Electrical         1
# FireplaceQu      690
# GarageType        81
# GarageYrBlt       81
# GarageFinish      81
# GarageQual        81
# GarageCond        81
# PoolQC          1453
# Fence           1179
# MiscFeature     1406
# dtype: int64

# %%
train=train.drop(['Alley', 'FireplaceQu','PoolQC', 'Fence', 'MiscFeature'], axis =1)
test=test.drop(['Alley', 'FireplaceQu','PoolQC', 'Fence', 'MiscFeature'], axis =1)
#null이 너무 많아서 빼기도 하고 , 데이터가 많아서 여유도 부리고, 열이 너무 많은것도 좋지 않다.

# %%
corr=train.corr() #상관계수
import seaborn as sns
import matplotlib.pyplot as plt

# %%
plt.figure(figsize=(10,10))
sns.heatmap(corr, cmap='YlGnBu',fmt=".1f", annot=False, square=True)

# %%
#quiz 
# 각 컬럼과 salesprice 컬럼간의 상관계수가 0.5보다 큰 대상에 대해서만 히트맵으로 출력하시오
corrSalePrice=corr[np.abs(corr['SalePrice'])>0.5].index
train=pd.DataFrame(train, columns=corrSalePrice)
corr=train.corr()
corr
# Out:
#               OverallQual  YearBuilt  YearRemodAdd  TotalBsmtSF  1stFlrSF  \
# OverallQual      1.000000   0.572323      0.550684     0.537808  0.476224
# YearBuilt        0.572323   1.000000      0.592855     0.391452  0.281986
# YearRemodAdd     0.550684   0.592855      1.000000     0.291066  0.240379
# TotalBsmtSF      0.537808   0.391452      0.291066     1.000000  0.819530
# 1stFlrSF         0.476224   0.281986      0.240379     0.819530  1.000000
# GrLivArea        0.593007   0.199010      0.287389     0.454868  0.566024
# FullBath         0.550600   0.468271      0.439046     0.323722  0.380637
# TotRmsAbvGrd     0.427452   0.095589      0.191740     0.285573  0.409516
# GarageCars       0.600671   0.537850      0.420622     0.434585  0.439317
# GarageArea       0.562022   0.478954      0.371600     0.486665  0.489782
# SalePrice        0.790982   0.522897      0.507101     0.613581  0.605852
#
#               GrLivArea  FullBath  TotRmsAbvGrd  GarageCars  GarageArea  \
# ...

# %%
plt.figure(figsize=(10,10))
sns.heatmap(corr, cmap='winter',fmt=".1f", annot=True, square=True)

# %%
plt.figure(figsize=(10,10))
sns.heatmap(corr, cmap='YlGnBu',fmt=".1f", annot=True, square=True)

# %%
plt.figure(figsize=(10,10))
sns.heatmap(train.corr()[abs(train.corr()) > 0.5], cmap='YlGnBu',fmt=".1f", annot=True, square=True)

# %% [markdown]
# ### 선생님 답

# %%
rev=corr.SalePrice[corr.SalePrice>0.5]
rev
# Out:
# OverallQual     0.790982
# YearBuilt       0.522897
# YearRemodAdd    0.507101
# TotalBsmtSF     0.613581
# 1stFlrSF        0.605852
# GrLivArea       0.708624
# FullBath        0.560664
# TotRmsAbvGrd    0.533723
# GarageCars      0.640409
# GarageArea      0.623431
# SalePrice       1.000000
# Name: SalePrice, dtype: float64

# %%
rev.index
# Out:
# Index(['OverallQual', 'YearBuilt', 'YearRemodAdd', 'TotalBsmtSF', '1stFlrSF',
#        'GrLivArea', 'FullBath', 'TotRmsAbvGrd', 'GarageCars', 'GarageArea',
#        'SalePrice'],
#       dtype='object')

# %%
rev.index.values #array로 자료구조변환
# Out:
# array(['OverallQual', 'YearBuilt', 'YearRemodAdd', 'TotalBsmtSF',
#        '1stFlrSF', 'GrLivArea', 'FullBath', 'TotRmsAbvGrd', 'GarageCars',
#        'GarageArea', 'SalePrice'], dtype=object)

# %%
rev_cols=list(rev.index.values)
rev_cols
# Out:
# ['OverallQual',
#  'YearBuilt',
#  'YearRemodAdd',
#  'TotalBsmtSF',
#  '1stFlrSF',
#  'GrLivArea',
#  'FullBath',
#  'TotRmsAbvGrd',
#  'GarageCars',
#  'GarageArea',
#  'SalePrice']

# %%
corr2=train[rev_cols].corr()
corr2
# Out:
#               OverallQual  YearBuilt  YearRemodAdd  TotalBsmtSF  1stFlrSF  \
# OverallQual      1.000000   0.572323      0.550684     0.537808  0.476224
# YearBuilt        0.572323   1.000000      0.592855     0.391452  0.281986
# YearRemodAdd     0.550684   0.592855      1.000000     0.291066  0.240379
# TotalBsmtSF      0.537808   0.391452      0.291066     1.000000  0.819530
# 1stFlrSF         0.476224   0.281986      0.240379     0.819530  1.000000
# GrLivArea        0.593007   0.199010      0.287389     0.454868  0.566024
# FullBath         0.550600   0.468271      0.439046     0.323722  0.380637
# TotRmsAbvGrd     0.427452   0.095589      0.191740     0.285573  0.409516
# GarageCars       0.600671   0.537850      0.420622     0.434585  0.439317
# GarageArea       0.562022   0.478954      0.371600     0.486665  0.489782
# SalePrice        0.790982   0.522897      0.507101     0.613581  0.605852
#
#               GrLivArea  FullBath  TotRmsAbvGrd  GarageCars  GarageArea  \
# ...

# %%
plt.figure(figsize=(10,10))
sns.heatmap(corr2, annot=True, annot_kws={'size':9},cmap='YlGnBu',fmt=".1f", square = True)
